# %% [markdown]
# # Modelo de Lenguaje GRU pequeño
#
# El siguiente notebook contiene cómo: cargar textos, tokenizar, construir ventanas de entrenamiento, entrenar un modelo `Embedding -> GRU -> Linear`, medir perplexity y generar muestras.
#
# Este notebook queda configurado por defecto para `multi3_nlu_es_hotels`, el dominio de hoteles de Multi3-NLU++.

# %% [markdown]
# ## 1. Instalacion y entorno
#
# En Colab puedes activar GPU en `Runtime > Change runtime type > T4 GPU` o similar. El codigo tambien funciona en CPU para los corpus pequenos, solo tarda mas.

# %%
#@title Instalacion y entorno
# !pip -q install datasets sentencepiece "sympy>=1.13.3,<1.14"

import csv
import glob
import json
import math
import random
import time
import re
import subprocess
from collections import Counter, defaultdict
from pathlib import Path

# Workaround for occasional Colab/PyTorch/SymPy import-state mismatches.
# If this cell was already run before the install line, restart the runtime once.
import sympy.core.symbol

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

from datasets import load_dataset

SEED = 42
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device:', device)
if device == 'cuda':
    print('gpu:', torch.cuda.get_device_name(0))
# Out:
# device: cpu

# %% [markdown]
# ## 2. Configuracion
#
# Para reproducir literalmente la version minima del reporte, deja `TOKENIZER = 'word'` o usa `char` si quieres un corpus ultrapequeno. El modelo por defecto usa embeddings de 128 y GRU de 256, dentro del rango recomendado.

# %%
#@title Hiperparametros y dataset
DATASET_NAME = 'multi3_nlu_es_hotels' #@param ['multi3_nlu_es_hotels', 'multi3_nlu_es_banking', 'multi3_nlu_es_all', 'toy_sintetico', 'simple_tico19_es', 'massive_es', 'mtop_es', 'tico19_es']
TOKENIZER = 'word' #@param ['word', 'char']
TEXT_FIELD_SIMPLE_TICO = 'simplification' #@param ['simplification', 'original']

LOWERCASE = True #@param {type:'boolean'}
NORMALIZE_SLOTS = True #@param {type:'boolean'}
MAX_TEXTS = 20000 #@param {type:'integer'}
MIN_FREQ = 1 #@param {type:'integer'}

SEQ_LEN = 48 #@param {type:'integer'}
STRIDE = 8 #@param {type:'integer'}
BATCH_SIZE = 64 #@param {type:'integer'}
EPOCHS = 11 #@param {type:'integer'}

EMB_DIM = 128 #@param {type:'integer'}
HIDDEN_DIM = 256 #@param {type:'integer'}
NUM_LAYERS = 1 #@param {type:'integer'}
LR = 1e-3 #@param {type:'number'}
WEIGHT_DECAY = 1e-4 #@param {type:'number'}
GRAD_CLIP = 1.0 #@param {type:'number'}
EARLY_STOP_PATIENCE = 3 #@param {type:'integer'}

# Parametros para la comparacion didactica
COMPARE_MODELS = True #@param {type:'boolean'}
COMPARISON_EPOCHS = 6 #@param {type:'integer'}
FF_CONTEXT_SIZE = 3 #@param {type:'integer'}
FF_HIDDEN_DIM = 256 #@param {type:'integer'}
FF_DROPOUT = 0.10 #@param {type:'number'}
NGRAM_ORDER = 4 #@param {type:'integer'}
NGRAM_ADD_K = 0.10 #@param {type:'number'}
TOPK_ANALYSIS = 8 #@param {type:'integer'}

assert TOKENIZER in {'word', 'char'}
assert DATASET_NAME in {'multi3_nlu_es_hotels', 'multi3_nlu_es_banking', 'multi3_nlu_es_all', 'toy_sintetico', 'simple_tico19_es', 'massive_es', 'mtop_es', 'tico19_es'}

# %% [markdown]
# ## 3. Carga de corpus
#
# Las funciones siguientes devuelven una lista de strings. Asi el resto del notebook no depende del formato original del dataset.

# %%
#@title Loaders de datasets espanoles
DATA_DIR = Path('data')
DATA_DIR.mkdir(exist_ok=True)

def run_cmd(cmd):
    print('+', ' '.join(cmd))
    subprocess.run(cmd, check=True)

def ensure_git_repo(url, path):
    path = Path(path)
    if not path.exists():
        run_cmd(['git', 'clone', '--depth', '1', url, str(path)])
    return path

def clean_text_list(texts):
    cleaned = []
    for text in texts:
        if not isinstance(text, str):
            continue
        text = re.sub(r'\s+', ' ', text.strip())
        if text:
            cleaned.append(text)
    return cleaned

def iter_json_records(obj):
    if isinstance(obj, list):
        for item in obj:
            yield from iter_json_records(item)
    elif isinstance(obj, dict):
        known = {'text', 'utterance', 'utt', 'sentence', 'original', 'simplification'}
        if known.intersection(obj.keys()):
            yield obj
        else:
            for value in obj.values():
                if isinstance(value, (dict, list)):
                    yield from iter_json_records(value)

def choose_text(record, preferred_keys):
    for key in preferred_keys:
        value = record.get(key)
        if isinstance(value, str) and value.strip():
            return value

    spanish_keys = ['es', 'es-ES', 'es_ES', 'spa', 'spa_Latn', 'spanish']
    for value in record.values():
        if isinstance(value, dict):
            for key in spanish_keys:
                nested = value.get(key)
                if isinstance(nested, str) and nested.strip():
                    return nested

    for value in record.values():
        if isinstance(value, str) and len(value.strip()) > 1:
            return value
    return None

def dataset_to_texts(ds, preferred_keys):
    texts = []
    if hasattr(ds, 'keys'):
        split_names = [s for s in ['train', 'validation', 'dev', 'test'] if s in ds]
        split_names = split_names or list(ds.keys())
        for split in split_names:
            for record in ds[split]:
                text = choose_text(record, preferred_keys)
                if text:
                    texts.append(text)
    else:
        for record in ds:
            text = choose_text(record, preferred_keys)
            if text:
                texts.append(text)
    return clean_text_list(texts)

def load_toy_sintetico(n=1500):
    alarm_times = ['a las 6', 'a las 7', 'a las 8', 'a las 9']
    days = ['hoy', 'manana', 'el lunes', 'el martes']
    alarm_forms = [
        'pon una alarma {day} {time}',
        'despiertame {day} {time}',
        'activa una alarma {day} {time}',
    ]
    cities = ['Monterrey', 'Madrid', 'Bogota', 'CDMX']
    weather_forms = [
        'que tiempo hara en {city}',
        'dime el clima en {city}',
        'como estara el tiempo en {city}',
    ]
    hotel_forms = [
        'quiero revisar mi reserva del hotel',
        'cancela mi reserva del hotel para manana',
        'necesito cambiar la fecha de llegada',
    ]
    rows = []
    for _ in range(n):
        family = random.choice(['alarm', 'weather', 'hotel'])
        if family == 'alarm':
            rows.append(random.choice(alarm_forms).format(day=random.choice(days), time=random.choice(alarm_times)))
        elif family == 'weather':
            rows.append(random.choice(weather_forms).format(city=random.choice(cities)))
        else:
            rows.append(random.choice(hotel_forms))
    return rows

def multi3_path_matches_domain(path, domain):
    if domain == 'all':
        return True
    parts = str(path).lower().replace('\\', '/').split('/')
    aliases = {
        'hotels': {'hotel', 'hotels'},
        'banking': {'bank', 'banking'},
    }.get(domain, {domain})
    return bool(aliases.intersection(parts))

def multi3_record_matches_domain(record, domain):
    if domain == 'all':
        return True
    uid = str(record.get('uid', '')).lower()
    if domain == 'hotels':
        return uid.startswith(('hotel_', 'hotels_'))
    if domain == 'banking':
        return uid.startswith(('bank_', 'banking_'))
    return False

def multi3_hf_json_paths(domain):
    from huggingface_hub import hf_hub_download, list_repo_files

    repo_id = 'uoe-nlp/multi3-nlu'
    files = list_repo_files(repo_id, repo_type='dataset')
    spanish_files = [p for p in files if p.startswith('spanish/') and p.endswith('.json')]
    domain_files = [p for p in spanish_files if multi3_path_matches_domain(p, domain)]
    selected_files = domain_files if domain_files else spanish_files
    paths = []
    for repo_file in selected_files:
        local_path = hf_hub_download(
            repo_id=repo_id,
            filename=repo_file,
            repo_type='dataset',
            local_dir=DATA_DIR / 'multi3-nlu-hf',
        )
        paths.append((Path(local_path), repo_file))
    return paths

def multi3_git_json_paths(domain):
    repo = ensure_git_repo('https://huggingface.co/datasets/uoe-nlp/multi3-nlu', DATA_DIR / 'multi3-nlu')
    all_paths = sorted(repo.glob('spanish/**/*.json'))
    domain_paths = [p for p in all_paths if multi3_path_matches_domain(p.relative_to(repo), domain)]
    selected_paths = domain_paths if domain_paths else all_paths
    return [(p, p.relative_to(repo).as_posix()) for p in selected_paths]

def load_multi3_nlu_es(domain='all'):
    texts = []
    try:
        json_paths = multi3_hf_json_paths(domain)
    except Exception as exc:
        print('No pude listar/descargar con huggingface_hub; intento git clone.', repr(exc))
        json_paths = multi3_git_json_paths(domain)

    if not json_paths:
        raise FileNotFoundError(f'No encontre archivos JSON espanoles para Multi3-NLU++ dominio={domain}')

    for fp, repo_file in json_paths:
        with fp.open(encoding='utf-8') as f:
            data = json.load(f)
        path_matches = multi3_path_matches_domain(repo_file, domain)
        for record in iter_json_records(data):
            if domain != 'all' and not (path_matches or multi3_record_matches_domain(record, domain)):
                continue
            text = choose_text(record, ['text', 'utterance', 'sentence'])
            if text:
                texts.append(text)

    texts = clean_text_list(texts)
    if not texts:
        raise ValueError(f'No encontre textos para Multi3-NLU++ dominio={domain}. Prueba multi3_nlu_es_all para diagnosticar.')
    return texts

def load_simple_tico19_es():
    repo = ensure_git_repo('https://github.com/MMU-TDMLab/SimpleTICO19.git', DATA_DIR / 'SimpleTICO19')
    texts = []
    csv_paths = sorted((repo / 'dataset').glob('simpletico19.*.es.csv'))
    for fp in csv_paths:
        with fp.open(encoding='utf-8', newline='') as f:
            reader = csv.DictReader(f)
            for row in reader:
                text = row.get(TEXT_FIELD_SIMPLE_TICO) or row.get('simplification') or row.get('original')
                if text:
                    texts.append(text)
    return clean_text_list(texts)

def load_massive_es():
    ds = load_dataset('AmazonScience/massive', 'es-ES')
    return dataset_to_texts(ds, ['utt', 'text', 'utterance'])

def load_mtop_es():
    last_error = None
    for args in [('tasksource/mtop', 'es'), ('tasksource/mtop',)]:
        try:
            ds = load_dataset(*args)
            texts = dataset_to_texts(ds, ['text', 'utterance', 'query', 'question'])
            if texts:
                return texts
        except Exception as exc:
            last_error = exc
    raise RuntimeError('No pude cargar MTOP desde Hugging Face') from last_error

def load_tico19_es():
    ds = load_dataset('SEACrowd/tico_19', trust_remote_code=True)
    return dataset_to_texts(ds, ['text', 'sentence', 'es', 'spa', 'spanish'])

LOADERS = {
    'toy_sintetico': load_toy_sintetico,
    'multi3_nlu_es_hotels': lambda: load_multi3_nlu_es('hotels'),
    'multi3_nlu_es_banking': lambda: load_multi3_nlu_es('banking'),
    'multi3_nlu_es_all': lambda: load_multi3_nlu_es('all'),
    'simple_tico19_es': load_simple_tico19_es,
    'massive_es': load_massive_es,
    'mtop_es': load_mtop_es,
    'tico19_es': load_tico19_es,
}

texts = LOADERS[DATASET_NAME]()
texts = clean_text_list(texts)
random.shuffle(texts)
if MAX_TEXTS and MAX_TEXTS > 0:
    texts = texts[:MAX_TEXTS]

if len(texts) < 3:
    raise ValueError(f'El corpus cargado es demasiado pequeno: {len(texts)} textos')

print(f'dataset: {DATASET_NAME}')
print(f'textos cargados: {len(texts):,}')
print('\nEjemplos:')
for sample_text in texts[:5]:
    print('-', sample_text[:220])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# dataset: multi3_nlu_es_hotels
# textos cargados: 1,009
#
# Ejemplos:
# - reserva una mesa para 5
# - ¿a qué hora abre el gimnasio en la mañana?
# - hasta el viernes
# - ¿Por qué el servicio de limpieza no limpió mi habitación esta mañana?
# - del 26 al 29 de mayo

# %% [markdown]
# ## 4. Normalizacion, tokenizacion y vocabulario
#
# Para corpus diminutos puedes usar `char`. Para Multi3-NLU++, Simple TICO-19 o MASSIVE, `word` suele ser suficiente para aprender la canalizacion completa antes de pasar a BPE.

# %%
#@title Tokenizacion y vocabulario
WORD_RE = re.compile(r"<[^>\s]+>|\w+|[^\w\s]", flags=re.UNICODE)

MONTHS_RE = r'enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|setiembre|octubre|noviembre|diciembre'
NUMBER_WORDS_RE = r'dos|tres|cuatro|cinco|seis|siete|ocho|nueve|diez|once|doce'

def normalize_slots(text):
    text = re.sub(r'\b\d{1,2}\s*[:.]\s*\d{2}\b', ' <hora> ', text)
    text = re.sub(r'\b\d{1,2}\s+y\s+(?:cuarto|media)\b', ' <hora> ', text, flags=re.IGNORECASE)
    text = re.sub(r'\b\d{1,2}\s+menos\s+\d{1,2}\b', ' <hora> ', text, flags=re.IGNORECASE)
    text = re.sub(r'\ba\s+l(?:a|as)\s+\d{1,2}\b', ' a las <hora> ', text, flags=re.IGNORECASE)
    text = re.sub(rf'\b({MONTHS_RE})\b', ' <mes> ', text, flags=re.IGNORECASE)
    text = re.sub(r'\b\d+\b', ' <num> ', text)
    text = re.sub(rf'\b({NUMBER_WORDS_RE})\b', ' <num> ', text, flags=re.IGNORECASE)
    return re.sub(r'\s+', ' ', text).strip()

def normalize(text):
    text = re.sub(r'\s+', ' ', text.strip())
    if LOWERCASE:
        text = text.lower()
    if NORMALIZE_SLOTS:
        text = normalize_slots(text)
    return text

def tokenize(text):
    text = normalize(text)
    if TOKENIZER == 'char':
        return list(text)
    return WORD_RE.findall(text)

split_at = max(1, int(0.9 * len(texts)))
train_texts = texts[:split_at]
val_texts = texts[split_at:] or texts[:max(1, min(100, len(texts)))]

counter = Counter()
for text in train_texts:
    counter.update(tokenize(text))

SPECIAL = ['<pad>', '<unk>', '<bos>', '<eos>']
itos = SPECIAL + [tok for tok, count in counter.most_common() if count >= MIN_FREQ and tok not in SPECIAL]
stoi = {tok: idx for idx, tok in enumerate(itos)}

PAD = stoi['<pad>']
UNK = stoi['<unk>']
BOS = stoi['<bos>']
EOS = stoi['<eos>']

def encode_texts(text_list):
    ids = []
    for text in text_list:
        ids.append(BOS)
        ids.extend(stoi.get(tok, UNK) for tok in tokenize(text))
        ids.append(EOS)
    return torch.tensor(ids, dtype=torch.long)

train_ids = encode_texts(train_texts)
val_ids = encode_texts(val_texts)
if len(val_ids) <= SEQ_LEN + 1:
    val_ids = train_ids.clone()

print(f'train_texts: {len(train_texts):,}')
print(f'val_texts: {len(val_texts):,}')
print(f'vocab_size: {len(itos):,}')
print(f'train_tokens: {len(train_ids):,}')
print(f'val_tokens: {len(val_ids):,}')
# Out:
# train_texts: 908
# val_texts: 101
# vocab_size: 1,028
# train_tokens: 10,272
# val_tokens: 1,155

# %% [markdown]
# ## 5. Dataset de ventanas causales
#
# Cada ejemplo usa `x = tokens[t:t+SEQ_LEN]` y `y = tokens[t+1:t+SEQ_LEN+1]`. Esa es la tarea clasica de predecir el siguiente token.

# %%
#@title Ventanas de entrenamiento
class WindowDataset(Dataset):
    def __init__(self, ids, seq_len=32, stride=1):
        if len(ids) <= seq_len + 1:
            raise ValueError('El corpus codificado es mas corto que SEQ_LEN. Reduce SEQ_LEN o carga mas texto.')
        self.ids = ids
        self.seq_len = seq_len
        self.stride = max(1, stride)
        self.n = 1 + (len(ids) - seq_len - 1) // self.stride

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        start = idx * self.stride
        x = self.ids[start : start + self.seq_len]
        y = self.ids[start + 1 : start + self.seq_len + 1]
        return x, y

train_ds = WindowDataset(train_ids, seq_len=SEQ_LEN, stride=STRIDE)
val_ds = WindowDataset(val_ids, seq_len=SEQ_LEN, stride=STRIDE)

train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_dl = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

print(f'train_windows: {len(train_ds):,}')
print(f'val_windows: {len(val_ds):,}')
# Out:
# train_windows: 1,278
# val_windows: 139

# %% [markdown]
# ## 6. Modelo minimo: Embedding -> GRU -> Linear
#
# Esta es la arquitectura recomendada en el reporte para empezar: pequena, facil de leer, y suficiente para aprender el flujo completo de un language model causal.

# %%
#@title Modelo GRU minimo
class TinyGRULM(nn.Module):
    def __init__(self, vocab_size, emb_dim=128, hidden_dim=256, num_layers=1):
        super().__init__()
        dropout = 0.1 if num_layers > 1 else 0.0
        self.emb = nn.Embedding(vocab_size, emb_dim, padding_idx=PAD)
        self.rnn = nn.GRU(
            emb_dim,
            hidden_dim,
            num_layers=num_layers,
            dropout=dropout,
            batch_first=True,
        )
        self.head = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, h=None):
        x = self.emb(x)
        out, h = self.rnn(x, h)
        logits = self.head(out)
        return logits, h

model = TinyGRULM(
    vocab_size=len(itos),
    emb_dim=EMB_DIM,
    hidden_dim=HIDDEN_DIM,
    num_layers=NUM_LAYERS,
).to(device)

opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
loss_fn = nn.CrossEntropyLoss(ignore_index=PAD)

n_params = sum(p.numel() for p in model.parameters())
print(model)
print(f'parametros: {n_params:,}')
# Out:
# TinyGRULM(
#   (emb): Embedding(1028, 128, padding_idx=0)
#   (rnn): GRU(128, 256, batch_first=True)
#   (head): Linear(in_features=256, out_features=1028, bias=True)
# )
# parametros: 692,228

# %% [markdown]
# ## 7. Entrenamiento y perplexity
#
# La perplexity deberia bajar rapido en `toy_sintetico`. En corpus reales puede bajar mas lento, pero aun asi deberias ver una tendencia clara si el dataset cargo bien.

# %%
#@title Loop de entrenamiento
def safe_ppl(avg_loss):
    return float('inf') if avg_loss > 20 else math.exp(avg_loss)

def run_epoch(loader, train=True):
    model.train(mode=train)
    total_loss = 0.0
    total_tokens = 0
    context = torch.enable_grad() if train else torch.no_grad()
    with context:
        for x, y in loader:
            x = x.to(device)
            y = y.to(device)
            logits, _ = model(x)
            loss = loss_fn(logits.reshape(-1, logits.size(-1)), y.reshape(-1))

            if train:
                opt.zero_grad(set_to_none=True)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
                opt.step()

            n_tokens = (y != PAD).sum().item()
            total_loss += loss.item() * n_tokens
            total_tokens += n_tokens

    avg_loss = total_loss / max(1, total_tokens)
    return avg_loss, safe_ppl(avg_loss)

history = []
gru_training_start_time = time.time()
best_val_loss = float('inf')
best_epoch = 0
best_state = None
epochs_without_improvement = 0

for epoch in range(1, EPOCHS + 1):
    train_loss, train_ppl = run_epoch(train_dl, train=True)
    val_loss, val_ppl = run_epoch(val_dl, train=False)
    improved = val_loss < best_val_loss

    if improved:
        best_val_loss = val_loss
        best_epoch = epoch
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1

    history.append({
        'epoch': epoch,
        'train_loss': train_loss,
        'val_loss': val_loss,
        'train_ppl': train_ppl,
        'val_ppl': val_ppl,
        'is_best': improved,
    })
    print(
        f'epoch={epoch:02d} '
        f'train_loss={train_loss:.4f} train_ppl={train_ppl:.2f} '
        f'val_loss={val_loss:.4f} val_ppl={val_ppl:.2f} '
        f"{'*best*' if improved else ''}"
    )

    if EARLY_STOP_PATIENCE and epochs_without_improvement >= EARLY_STOP_PATIENCE:
        print(f'Early stopping: sin mejora en {EARLY_STOP_PATIENCE} epocas.')
        break

if best_state is not None:
    model.load_state_dict({k: v.to(device) for k, v in best_state.items()})
    print(f'Modelo restaurado desde epoch={best_epoch} con best_val_loss={best_val_loss:.4f}')


gru_train_seconds = time.time() - gru_training_start_time
print(f'Tiempo entrenamiento GRU: {gru_train_seconds:.1f} s')
# Out:
# epoch=01 train_loss=5.6249 train_ppl=277.25 val_loss=4.5820 val_ppl=97.71 *best*
# epoch=02 train_loss=4.0942 train_ppl=59.99 val_loss=4.0523 val_ppl=57.53 *best*
# epoch=03 train_loss=3.5471 train_ppl=34.71 val_loss=3.7421 val_ppl=42.19 *best*
# epoch=04 train_loss=3.1630 train_ppl=23.64 val_loss=3.5684 val_ppl=35.46 *best*
# epoch=05 train_loss=2.8779 train_ppl=17.78 val_loss=3.4448 val_ppl=31.34 *best*
# epoch=06 train_loss=2.6455 train_ppl=14.09 val_loss=3.3693 val_ppl=29.06 *best*
# epoch=07 train_loss=2.4422 train_ppl=11.50 val_loss=3.3140 val_ppl=27.49 *best*
# epoch=08 train_loss=2.2580 train_ppl=9.56 val_loss=3.2807 val_ppl=26.59 *best*
# epoch=09 train_loss=2.0935 train_ppl=8.11 val_loss=3.2525 val_ppl=25.86 *best*
# epoch=10 train_loss=1.9431 train_ppl=6.98 val_loss=3.2481 val_ppl=25.74 *best*
# epoch=11 train_loss=1.8071 train_ppl=6.09 val_loss=3.2430 val_ppl=25.61 *best*
# Modelo restaurado desde epoch=11 con best_val_loss=3.2430
# Tiempo entrenamiento GRU: 62.8 s

# %% [markdown]
# ## 8. Generacion
#
# La generacion aqui usa muestreo multinomial con temperatura y `top_k`. Para corpus pequenos, prueba temperaturas entre `0.7` y `1.0`.

# %%
#@title Muestreo de texto
@torch.no_grad()
def sample(prompt='quiero revisar', max_new=18, temperature=0.55, top_k=6):
    model.eval()
    token_ids = [BOS] + [stoi.get(tok, UNK) for tok in tokenize(prompt)]

    for _ in range(max_new):
        context = torch.tensor([token_ids[-SEQ_LEN:]], dtype=torch.long, device=device)
        logits, _ = model(context)
        logits = logits[:, -1, :] / max(temperature, 1e-6)

        if top_k and top_k > 0 and top_k < logits.size(-1):
            values, _ = torch.topk(logits, top_k)
            cutoff = values[:, -1].unsqueeze(-1)
            logits = torch.where(logits < cutoff, torch.full_like(logits, -float('inf')), logits)

        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1).item()
        if next_id == EOS:
            break
        token_ids.append(next_id)

    out_tokens = [itos[i] for i in token_ids[1:] if i not in {PAD, EOS}]
    if TOKENIZER == 'char':
        return ''.join(tok for tok in out_tokens if tok not in {'<bos>', '<unk>'})

    text = ' '.join(tok for tok in out_tokens if tok != '<bos>')
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    return text

SAMPLE_MAX_NEW = 18
SAMPLE_TEMPERATURE = 0.55
SAMPLE_TOP_K = 6
SAMPLES_PER_PROMPT = 3
RENDER_SAMPLE_SLOTS = True

SLOT_RENDER_VALUES = {
    '<num>': ['1', '2', '3', '4', '5'],
    '<mes>': ['junio', 'julio', 'agosto', 'septiembre'],
    '<hora>': ['7:00', '8:30', '12:00', '18:00'],
}

def render_slots(text):
    def repl(match):
        token = match.group(0)
        return random.choice(SLOT_RENDER_VALUES.get(token, [token]))
    return re.sub(r'<num>|<mes>|<hora>', repl, text)

TOY_PROMPTS = ['quiero', 'pon una alarma', 'los sintomas', 'reserva del hotel']
HOTEL_PROMPTS = ['quiero reservar una habitación', 'necesito cambiar mi reserva', 'reserva del hotel por', 'quiero una habitación para']
DEFAULT_PROMPTS = ['quiero', 'necesito', 'dime', 'puedo']

if DATASET_NAME == 'toy_sintetico':
    prompts = TOY_PROMPTS
elif DATASET_NAME == 'multi3_nlu_es_hotels':
    prompts = HOTEL_PROMPTS
else:
    prompts = DEFAULT_PROMPTS

generated_samples = []
for prompt in prompts:
    for sample_idx in range(1, SAMPLES_PER_PROMPT + 1):
        generated = sample(prompt=prompt, max_new=SAMPLE_MAX_NEW, temperature=SAMPLE_TEMPERATURE, top_k=SAMPLE_TOP_K)
        rendered = render_slots(generated) if RENDER_SAMPLE_SLOTS else generated
        generated_samples.append({'prompt': prompt, 'sample_idx': sample_idx, 'text': generated, 'rendered_text': rendered})
        print(f'PROMPT: {prompt} [{sample_idx}]')
        print(generated)
        if RENDER_SAMPLE_SLOTS and rendered != generated:
            print('rendered:', rendered)
        print()
# Out:
# PROMPT: quiero reservar una habitación [1]
# quiero reservar una habitación para <num> adultos y un niño
# rendered: quiero reservar una habitación para 3 adultos y un niño
#
# PROMPT: quiero reservar una habitación [2]
# quiero reservar una habitación desde el <num> de <mes>
# rendered: quiero reservar una habitación desde el 5 de julio
#
# PROMPT: quiero reservar una habitación [3]
# quiero reservar una habitación para <num> adultos
# rendered: quiero reservar una habitación para 4 adultos
#
# PROMPT: necesito cambiar mi reserva [1]
# necesito cambiar mi reserva de habitación para el <num> de <mes>
# rendered: necesito cambiar mi reserva de habitación para el 1 de julio
#
# PROMPT: necesito cambiar mi reserva [2]
# necesito cambiar mi reserva para el <num> de <mes>
# rendered: necesito cambiar mi reserva para el 2 de agosto
#
# PROMPT: necesito cambiar mi reserva [3]
# necesito cambiar mi reserva de hotel
#
# PROMPT: reserva del hotel por [1]
# reserva del hotel por <num> noches desde el <num> de <mes>
# rendered: reserva del hotel por 2 noches desde el 1 de junio
#
# PROMPT: reserva del hotel por [2]
# reserva del hotel por <num> noches
# rendered: reserva del hotel por 2 noches
#
# PROMPT: reserva del hotel por [3]
# reserva del hotel por <num> noches
# rendered: reserva del hotel por 3 noches
#
# PROMPT: quiero una habitación para [1]
# quiero una habitación para <num> adultos
# rendered: quiero una habitación para 5 adultos
#
# PROMPT: quiero una habitación para [2]
# quiero una habitación para <num> adultos y <num> niños
# rendered: quiero una habitación para 5 adultos y 3 niños
#
# PROMPT: quiero una habitación para [3]
# quiero una habitación para <num> personas
# rendered: quiero una habitación para 4 personas

# %% [markdown]
# ## 9. Comparación didáctica: n-grama, red feedforward y GRU
#
# El objetivo de esta sección es comparar tres maneras de modelar la misma tarea:
#
# 1. **n-grama de conteos:** estima probabilidades con frecuencias de contextos exactos y backoff.
# 2. **red feedforward de ventana fija:** usa embeddings compartidos de los últimos `FF_CONTEXT_SIZE` tokens, concatena esos vectores y predice el siguiente token con una capa oculta y softmax.
# 3. **GRU:** mantiene un estado recurrente que resume el contexto visto dentro de la ventana de entrenamiento.
#
# Todos usan el mismo corpus, la misma tokenización, el mismo vocabulario y la misma partición entrenamiento/validación. La métrica principal es la pérdida promedio por token y la perplexity de validación. Además se agregan visualizaciones de curvas de entrenamiento, comparación de perplexity, número de parámetros/eventos almacenados, distribuciones de siguiente token y ejemplos generados con los mismos prompts.

# %%
#@title Utilidades comunes para comparacion
def count_trainable_params(m):
    return sum(p.numel() for p in m.parameters() if p.requires_grad)

def get_logits(model_output):
    # TinyGRULM regresa (logits, h); otros modelos pueden regresar solo logits.
    if isinstance(model_output, (tuple, list)):
        return model_output[0]
    return model_output

def evaluate_torch_lm(current_model, loader):
    current_model.eval()
    total_loss = 0.0
    total_tokens = 0
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            y = y.to(device)
            logits = get_logits(current_model(x))
            loss = loss_fn(logits.reshape(-1, logits.size(-1)), y.reshape(-1))
            n_tokens = (y != PAD).sum().item()
            total_loss += loss.item() * n_tokens
            total_tokens += n_tokens
    avg_loss = total_loss / max(1, total_tokens)
    return avg_loss, safe_ppl(avg_loss)

def train_torch_lm(current_model, model_name, epochs=COMPARISON_EPOCHS):
    current_model = current_model.to(device)
    opt_local = torch.optim.AdamW(current_model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    local_history = []
    best_state = None
    best_val = float('inf')
    start_time = time.time()

    for epoch in range(1, epochs + 1):
        current_model.train()
        total_loss = 0.0
        total_tokens = 0

        for x, y in train_dl:
            x = x.to(device)
            y = y.to(device)
            logits = get_logits(current_model(x))
            loss = loss_fn(logits.reshape(-1, logits.size(-1)), y.reshape(-1))

            opt_local.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(current_model.parameters(), GRAD_CLIP)
            opt_local.step()

            n_tokens = (y != PAD).sum().item()
            total_loss += loss.item() * n_tokens
            total_tokens += n_tokens

        train_loss = total_loss / max(1, total_tokens)
        train_ppl = safe_ppl(train_loss)
        val_loss, val_ppl = evaluate_torch_lm(current_model, val_dl)
        improved = val_loss < best_val

        if improved:
            best_val = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in current_model.state_dict().items()}

        local_history.append({
            'model': model_name,
            'epoch': epoch,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_ppl': train_ppl,
            'val_ppl': val_ppl,
            'is_best': improved,
        })

        print(
            f'{model_name} epoch={epoch:02d} '
            f'train_loss={train_loss:.4f} train_ppl={train_ppl:.2f} '
            f'val_loss={val_loss:.4f} val_ppl={val_ppl:.2f} '
            f"{'*best*' if improved else ''}"
        )

    if best_state is not None:
        current_model.load_state_dict({k: v.to(device) for k, v in best_state.items()})

    elapsed = time.time() - start_time
    return current_model, local_history, elapsed

def encode_prompt(prompt):
    return [BOS] + [stoi.get(tok, UNK) for tok in tokenize(prompt)]

def decode_ids(token_ids):
    out_tokens = [itos[i] for i in token_ids if i not in {PAD, BOS, EOS}]
    if TOKENIZER == 'char':
        return ''.join(tok for tok in out_tokens if tok != '<unk>')
    text = ' '.join(tok for tok in out_tokens)
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    return text.strip()

@torch.no_grad()
def sample_torch_lm(current_model, prompt, max_new=18, temperature=0.55, top_k=6):
    current_model.eval()
    token_ids = encode_prompt(prompt)

    for _ in range(max_new):
        context = torch.tensor([token_ids[-SEQ_LEN:]], dtype=torch.long, device=device)
        logits = get_logits(current_model(context))
        logits = logits[:, -1, :] / max(temperature, 1e-6)

        # Evitamos generar tokens tecnicos que no son utiles en la lectura cualitativa.
        for special_id in [PAD, BOS, UNK]:
            logits[:, special_id] = -float('inf')

        if top_k and top_k > 0 and top_k < logits.size(-1):
            values, _ = torch.topk(logits, top_k)
            cutoff = values[:, -1].unsqueeze(-1)
            logits = torch.where(logits < cutoff, torch.full_like(logits, -float('inf')), logits)

        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1).item()
        if next_id == EOS:
            break
        token_ids.append(next_id)

    return decode_ids(token_ids[1:])

@torch.no_grad()
def next_token_table_torch(current_model, prompt, top_k=TOPK_ANALYSIS):
    current_model.eval()
    token_ids = encode_prompt(prompt)
    context = torch.tensor([token_ids[-SEQ_LEN:]], dtype=torch.long, device=device)
    logits = get_logits(current_model(context))[:, -1, :]
    for special_id in [PAD, BOS, UNK]:
        logits[:, special_id] = -float('inf')
    probs = torch.softmax(logits, dim=-1).squeeze(0).detach().cpu()
    values, ids = torch.topk(probs, k=min(top_k, len(itos)))
    return pd.DataFrame({
        'token': [itos[i] for i in ids.tolist()],
        'prob': values.tolist(),
    })

# %%
#@title Modelo feedforward de ventana fija: Embedding -> concatenacion -> capa oculta -> softmax
class FeedForwardNGramLM(nn.Module):
    """Red neuronal de lenguaje de ventana fija, similar al esquema de Bengio/Jurafsky.

    Para cada posicion de una secuencia, toma los ultimos `context_size` tokens visibles,
    obtiene sus embeddings compartidos, concatena esos vectores y predice el siguiente token.
    """
    def __init__(self, vocab_size, emb_dim=128, hidden_dim=256, context_size=3, dropout=0.1):
        super().__init__()
        self.context_size = int(context_size)
        self.emb = nn.Embedding(vocab_size, emb_dim, padding_idx=PAD)
        self.proj = nn.Linear(self.context_size * emb_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.head = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x):
        # x: (batch, tiempo). Para cada posicion t se usan tokens anteriores dentro de x.
        # Ejemplo con context_size=3: [w_{t-2}, w_{t-1}, w_t] -> predice y_t = w_{t+1}.
        left_pad = self.context_size - 1
        padded = F.pad(x, (left_pad, 0), value=PAD)
        contexts = padded.unfold(dimension=1, size=self.context_size, step=1)  # (B, T, N)
        emb = self.emb(contexts)  # (B, T, N, d)
        flat = emb.reshape(emb.size(0), emb.size(1), -1)
        hidden = torch.relu(self.proj(flat))
        hidden = self.dropout(hidden)
        logits = self.head(hidden)
        return logits

if COMPARE_MODELS:
    gru_model = model
    gru_eval_loss, gru_eval_ppl = evaluate_torch_lm(gru_model, val_dl)
    gru_param_count = count_trainable_params(gru_model)

    ff_model = FeedForwardNGramLM(
        vocab_size=len(itos),
        emb_dim=EMB_DIM,
        hidden_dim=FF_HIDDEN_DIM,
        context_size=FF_CONTEXT_SIZE,
        dropout=FF_DROPOUT,
    ).to(device)

    print(ff_model)
    print(f'parametros feedforward: {count_trainable_params(ff_model):,}')
    print(f'parametros GRU:         {gru_param_count:,}')
    ff_model, ff_history, ff_train_seconds = train_torch_lm(
        ff_model,
        'Feedforward',
        epochs=COMPARISON_EPOCHS,
    )
else:
    print('COMPARE_MODELS=False: se omite entrenamiento feedforward.')
# Out:
# FeedForwardNGramLM(
#   (emb): Embedding(1028, 128, padding_idx=0)
#   (proj): Linear(in_features=384, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (head): Linear(in_features=256, out_features=1028, bias=True)
# )
# parametros feedforward: 494,340
# parametros GRU:         692,228
# Feedforward epoch=01 train_loss=5.3764 train_ppl=216.23 val_loss=4.2998 val_ppl=73.69 *best*
# Feedforward epoch=02 train_loss=3.7152 train_ppl=41.07 val_loss=3.7440 val_ppl=42.27 *best*
# Feedforward epoch=03 train_loss=3.1150 train_ppl=22.53 val_loss=3.5226 val_ppl=33.87 *best*
# Feedforward epoch=04 train_loss=2.7002 train_ppl=14.88 val_loss=3.4184 val_ppl=30.52 *best*
# Feedforward epoch=05 train_loss=2.3569 train_ppl=10.56 val_loss=3.3770 val_ppl=29.28 *best*
# Feedforward epoch=06 train_loss=2.0454 train_ppl=7.73 val_loss=3.3919 val_ppl=29.72

# %%
#@title Modelo n-grama de conteos con add-k smoothing y backoff
class BackoffNGramLM:
    """Modelo n-grama simple para fines didacticos.

    order=4 significa un 4-grama: P(w_t | w_{t-3}, w_{t-2}, w_{t-1}).
    Si el contexto largo no se vio, retrocede a contextos mas cortos.
    """
    def __init__(self, vocab_size, order=4, add_k=0.1):
        self.vocab_size = int(vocab_size)
        self.order = int(order)
        self.max_context = max(0, self.order - 1)
        self.add_k = float(add_k)
        self.context_to_next = defaultdict(Counter)
        self.context_totals = Counter()

    def fit(self, ids):
        ids = [int(x) for x in ids]
        for i in range(1, len(ids)):
            target = ids[i]
            if target == PAD:
                continue
            for context_len in range(0, self.max_context + 1):
                start = max(0, i - context_len)
                context = tuple(ids[start:i])
                self.context_to_next[context][target] += 1
                self.context_totals[context] += 1
        return self

    def prob(self, target_id, context_ids):
        context_ids = [int(x) for x in context_ids]
        max_len = min(self.max_context, len(context_ids))
        for context_len in range(max_len, -1, -1):
            context = tuple(context_ids[-context_len:]) if context_len > 0 else tuple()
            counts = self.context_to_next.get(context)
            total = self.context_totals.get(context, 0)
            if counts and total > 0:
                return (counts.get(int(target_id), 0) + self.add_k) / (total + self.add_k * self.vocab_size)
        return 1.0 / self.vocab_size

    def next_probs(self, context_ids):
        probs = np.array([self.prob(i, context_ids) for i in range(self.vocab_size)], dtype=np.float64)
        # No queremos que la generacion produzca padding, BOS o UNK.
        probs[[PAD, BOS, UNK]] = 0.0
        total = probs.sum()
        if total <= 0:
            probs[:] = 1.0 / self.vocab_size
            probs[[PAD, BOS, UNK]] = 0.0
            total = probs.sum()
        return probs / total

    def evaluate(self, ids):
        ids = [int(x) for x in ids]
        total_nll = 0.0
        total_tokens = 0
        for i in range(1, len(ids)):
            target = ids[i]
            if target == PAD:
                continue
            context = ids[max(0, i - self.max_context):i]
            p = max(self.prob(target, context), 1e-12)
            total_nll -= math.log(p)
            total_tokens += 1
        avg_loss = total_nll / max(1, total_tokens)
        return avg_loss, safe_ppl(avg_loss)

    def sample(self, prompt, max_new=18, temperature=0.55, top_k=6):
        token_ids = encode_prompt(prompt)

        for _ in range(max_new):
            probs = self.next_probs(token_ids[-self.max_context:])

            if temperature and temperature != 1.0:
                logits = np.log(np.maximum(probs, 1e-12)) / max(temperature, 1e-6)
                probs = np.exp(logits - logits.max())
                probs = probs / probs.sum()

            if top_k and top_k > 0 and top_k < len(probs):
                top_ids = np.argpartition(probs, -top_k)[-top_k:]
                mask = np.zeros_like(probs)
                mask[top_ids] = probs[top_ids]
                probs = mask / mask.sum()

            next_id = int(np.random.choice(np.arange(len(probs)), p=probs))
            if next_id == EOS:
                break
            token_ids.append(next_id)

        return decode_ids(token_ids[1:])

    def next_token_table(self, prompt, top_k=TOPK_ANALYSIS):
        token_ids = encode_prompt(prompt)
        probs = self.next_probs(token_ids[-self.max_context:])
        top_ids = probs.argsort()[::-1][:top_k]
        return pd.DataFrame({
            'token': [itos[i] for i in top_ids],
            'prob': probs[top_ids].tolist(),
        })

    def stored_events(self):
        return sum(len(next_counts) for next_counts in self.context_to_next.values())

if COMPARE_MODELS:
    ngram_train_start = time.time()
    ngram_model = BackoffNGramLM(
        vocab_size=len(itos),
        order=NGRAM_ORDER,
        add_k=NGRAM_ADD_K,
    ).fit(train_ids.tolist())
    ngram_train_seconds = time.time() - ngram_train_start
    ngram_loss, ngram_ppl = ngram_model.evaluate(val_ids.tolist())

    print(f'order: {ngram_model.order}')
    print(f'max_context: {ngram_model.max_context}')
    print(f'contextos almacenados: {len(ngram_model.context_to_next):,}')
    print(f'eventos condicionados almacenados: {ngram_model.stored_events():,}')
    print(f'val_loss={ngram_loss:.4f} val_ppl={ngram_ppl:.2f}')
else:
    print('COMPARE_MODELS=False: se omite modelo n-grama.')
# Out:
# order: 4
# max_context: 3
# contextos almacenados: 10,198
# eventos condicionados almacenados: 17,570
# val_loss=4.7395 val_ppl=114.38

# %%
#@title Tabla comparativa y visualizaciones
if COMPARE_MODELS:
    ff_eval_loss, ff_eval_ppl = evaluate_torch_lm(ff_model, val_dl)

    comparison_rows = [
        {
            'model': 'n-grama conteos',
            'contexto': f'{NGRAM_ORDER}-grama: ultimos {NGRAM_ORDER-1} tokens exactos + backoff',
            'trainable_params': 0,
            'stored_events_or_params': ngram_model.stored_events(),
            'val_loss': ngram_loss,
            'val_ppl': ngram_ppl,
            'train_seconds': ngram_train_seconds,
        },
        {
            'model': 'feedforward ventana fija',
            'contexto': f'ultimos {FF_CONTEXT_SIZE} tokens -> embeddings concatenados',
            'trainable_params': count_trainable_params(ff_model),
            'stored_events_or_params': count_trainable_params(ff_model),
            'val_loss': ff_eval_loss,
            'val_ppl': ff_eval_ppl,
            'train_seconds': ff_train_seconds,
        },
        {
            'model': 'GRU',
            'contexto': f'estado recurrente sobre ventanas de {SEQ_LEN} tokens',
            'trainable_params': gru_param_count,
            'stored_events_or_params': gru_param_count,
            'val_loss': gru_eval_loss,
            'val_ppl': gru_eval_ppl,
            'train_seconds': globals().get('gru_train_seconds', np.nan),
        },
    ]

    comparison_df = pd.DataFrame(comparison_rows).sort_values('val_ppl')
    display(comparison_df)

    # Curvas de entrenamiento para los dos modelos neuronales.
    curves = []
    for row in history:
        row2 = dict(row)
        row2['model'] = 'GRU'
        curves.append(row2)
    curves.extend(ff_history)
    curves_df = pd.DataFrame(curves)

    plt.figure(figsize=(7, 4))
    for model_name, group in curves_df.groupby('model'):
        plt.plot(group['epoch'], group['val_loss'], marker='o', label=model_name)
    plt.xlabel('Epoca')
    plt.ylabel('Loss de validacion por token')
    plt.title('Curvas de validacion')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    plt.figure(figsize=(7, 4))
    plt.bar(comparison_df['model'], comparison_df['val_ppl'])
    plt.ylabel('Perplexity de validacion')
    plt.title('Comparacion de perplexity')
    plt.xticks(rotation=20, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.show()

    plt.figure(figsize=(7, 4))
    plt.bar(comparison_df['model'], comparison_df['stored_events_or_params'])
    plt.yscale('log')
    plt.ylabel('Parametros entrenables o eventos almacenados (escala log)')
    plt.title('Tamano aproximado de cada modelo')
    plt.xticks(rotation=20, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.show()
else:
    print('COMPARE_MODELS=False')
# Out:
#                       model                                       contexto  \
# 2                       GRU  estado recurrente sobre ventanas de 48 tokens
# 1  feedforward ventana fija    ultimos 3 tokens -> embeddings concatenados
# 0           n-grama conteos    4-grama: ultimos 3 tokens exactos + backoff
#
#    trainable_params  stored_events_or_params  val_loss     val_ppl  \
# 2            692228                   692228  3.243019   25.610914
# 1            494340                   494340  3.376983   29.282281
# 0                 0                    17570  4.739536  114.381109
#
#    train_seconds
# 2      62.798991
# 1      21.461025
# 0       0.065457

# %%
#@title Comparar distribuciones de siguiente token y ejemplos generados
if COMPARE_MODELS:
    def compare_next_token_distributions(prompt, top_k=TOPK_ANALYSIS):
        tables = []
        for model_name, table in [
            ('n-grama conteos', ngram_model.next_token_table(prompt, top_k=top_k)),
            ('feedforward ventana fija', next_token_table_torch(ff_model, prompt, top_k=top_k)),
            ('GRU', next_token_table_torch(gru_model, prompt, top_k=top_k)),
        ]:
            table = table.copy()
            table.insert(0, 'model', model_name)
            tables.append(table)
        out = pd.concat(tables, ignore_index=True)
        return out

    analysis_prompt = prompts[0] if prompts else 'quiero'
    next_token_df = compare_next_token_distributions(analysis_prompt, top_k=TOPK_ANALYSIS)
    print('Prompt analizado:', analysis_prompt)
    display(next_token_df)

    # Para graficar, usamos la union de los tokens top-k de los tres modelos.
    pivot = next_token_df.pivot_table(index='token', columns='model', values='prob', aggfunc='max').fillna(0.0)
    pivot.plot(kind='bar', figsize=(9, 4))
    plt.ylabel('Probabilidad asignada')
    plt.title(f'Distribucion del siguiente token: "{analysis_prompt}"')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.show()

    comparison_samples = []
    for prompt in prompts[:min(4, len(prompts))]:
        for sample_idx in range(1, SAMPLES_PER_PROMPT + 1):
            comparison_samples.append({
                'model': 'n-grama conteos',
                'prompt': prompt,
                'sample_idx': sample_idx,
                'text': ngram_model.sample(
                    prompt=prompt,
                    max_new=SAMPLE_MAX_NEW,
                    temperature=SAMPLE_TEMPERATURE,
                    top_k=SAMPLE_TOP_K,
                ),
            })
            comparison_samples.append({
                'model': 'feedforward ventana fija',
                'prompt': prompt,
                'sample_idx': sample_idx,
                'text': sample_torch_lm(
                    ff_model,
                    prompt=prompt,
                    max_new=SAMPLE_MAX_NEW,
                    temperature=SAMPLE_TEMPERATURE,
                    top_k=SAMPLE_TOP_K,
                ),
            })
            comparison_samples.append({
                'model': 'GRU',
                'prompt': prompt,
                'sample_idx': sample_idx,
                'text': sample_torch_lm(
                    gru_model,
                    prompt=prompt,
                    max_new=SAMPLE_MAX_NEW,
                    temperature=SAMPLE_TEMPERATURE,
                    top_k=SAMPLE_TOP_K,
                ),
            })

    comparison_samples_df = pd.DataFrame(comparison_samples)
    display(comparison_samples_df)

    # Vista compacta: un ejemplo por modelo para cada prompt.
    display(comparison_samples_df.groupby(['prompt', 'model']).head(1).reset_index(drop=True))
else:
    print('COMPARE_MODELS=False')
# Out:
# Prompt analizado: quiero reservar una habitación
#                        model     token      prob
# 0            n-grama conteos      para  0.044934
# 1            n-grama conteos        en  0.018502
# 2            n-grama conteos        de  0.009692
# 3            n-grama conteos       con  0.009692
# 4            n-grama conteos    simple  0.009692
# 5            n-grama conteos     desde  0.009692
# 6            n-grama conteos     lobby  0.000881
# 7            n-grama conteos       van  0.000881
# 8   feedforward ventana fija      para  0.336870
# 9   feedforward ventana fija     doble  0.110781
# 10  feedforward ventana fija        en  0.104737
# 11  feedforward ventana fija  familiar  0.071338
# 12  feedforward ventana fija    simple  0.059633
# 13  feedforward ventana fija       con  0.051428
# 14  feedforward ventana fija        de  0.045165
# 15  feedforward ventana fija     <eos>  0.038117
# 16                       GRU      para  0.357979
# 17                       GRU       con  0.095074
# 18                       GRU  familiar  0.064844
# 19                       GRU     doble  0.058390
# 20                       GRU        en  0.057847
# 21                       GRU     desde  0.051289
# 22                       GRU       más  0.039238
# 23                       GRU    simple  0.025767
#                        model                          prompt  sample_idx  \
# 0            n-grama conteos  quiero reservar una habitación           1
# 1   feedforward ventana fija  quiero reservar una habitación           1
# 2                        GRU  quiero reservar una habitación           1
# 3            n-grama conteos  quiero reservar una habitación           2
# 4   feedforward ventana fija  quiero reservar una habitación           2
# 5                        GRU  quiero reservar una habitación           2
# 6            n-grama conteos  quiero reservar una habitación           3
# 7   feedforward ventana fija  quiero reservar una habitación           3
# 8                        GRU  quiero reservar una habitación           3
# 9            n-grama conteos     necesito cambiar mi reserva           1
# 10  feedforward ventana fija     necesito cambiar mi reserva           1
# 11                       GRU     necesito cambiar mi reserva           1
# 12           n-grama conteos     necesito cambiar mi reserva           2
# 13  feedforward ventana fija     necesito cambiar mi reserva           2
# 14                       GRU     necesito cambiar mi reserva           2
# 15           n-grama conteos     necesito cambiar mi reserva           3
# 16  feedforward ventana fija     necesito cambiar mi reserva           3
# 17                       GRU     necesito cambiar mi reserva           3
# 18           n-grama conteos           reserva del hotel por           1
# 19  feedforward ventana fija           reserva del hotel por           1
# 20                       GRU           reserva del hotel por           1
# 21           n-grama conteos           reserva del hotel por           2
# 22  feedforward ventana fija           reserva del hotel por           2
# 23                       GRU           reserva del hotel por           2
# 24           n-grama conteos           reserva del hotel por           3
# 25  feedforward ventana fija           reserva del hotel por           3
# 26                       GRU           reserva del hotel por           3
# 27           n-grama conteos      quiero una habitación para           1
# 28  feedforward ventana fija      quiero una habitación para           1
# 29                       GRU      quiero una habitación para           1
# 30           n-grama conteos      quiero una habitación para           2
# 31  feedforward ventana fija      quiero una habitación para           2
# 32                       GRU      quiero una habitación para           2
# 33           n-grama conteos      quiero una habitación para           3
# 34  feedforward ventana fija      quiero una habitación para           3
# 35                       GRU      quiero una habitación para           3
#
#                                                  text
# 0   quiero reservar una habitación para <num> adul...
# 1   quiero reservar una habitación para <num> adul...
# 2   quiero reservar una habitación para <num> adul...
# 3   quiero reservar una habitación para <num> noch...
# 4   quiero reservar una habitación para <num> adul...
# 5      quiero reservar una habitación para esta noche
# 6   quiero reservar una habitación para <num> adul...
# 7   quiero reservar una habitación para <num> adul...
# 8      quiero reservar una habitación con <num> niños
# 9   necesito cambiar mi reserva de habitación a no...
# 10               necesito cambiar mi reserva de hotel
# 11  necesito cambiar mi reserva a nombre de norman...
# 12  necesito cambiar mi reserva para una cena, mi ...
# 13  necesito cambiar mi reserva de habitación para...
# 14  necesito cambiar mi reserva de restaurante a l...
# 15    necesito cambiar mi reserva a una suite prémium
# 16               necesito cambiar mi reserva de hotel
# 17  necesito cambiar mi reserva de mi habitación, ...
# 18  reserva del hotel por <num> noches desde el <n...
# 19                        reserva del hotel por favor
# 20                 reserva del hotel por <num> noches
# 21        reserva del hotel por una ofrecéis masajes?
# 22                   reserva del hotel por una semana
# 23                 reserva del hotel por <num> noches
# 24  reserva del hotel por una noche para el próxim...
# 25      reserva del hotel por <num> noches, por favor
# 26  reserva del hotel por <num> noches desde el <n...
# 27           quiero una habitación para <num> adultos
# 28  quiero una habitación para <num> adultos y <nu...
# 29  quiero una habitación para <num> personas a la...
# 30  quiero una habitación para <num> adultos y <nu...
# 31  quiero una habitación para <num> adultos y <nu...
# 32  quiero una habitación para <num> adultos y <nu...
# 33  quiero una habitación para <num> adultos y <nu...
# 34  quiero una habitación para <num> adultos y un ...
# 35  quiero una habitación para <num> adultos y <nu...
#                        model                          prompt  sample_idx  \
# 0            n-grama conteos  quiero reservar una habitación           1
# 1   feedforward ventana fija  quiero reservar una habitación           1
# 2                        GRU  quiero reservar una habitación           1
# 3            n-grama conteos     necesito cambiar mi reserva           1
# 4   feedforward ventana fija     necesito cambiar mi reserva           1
# 5                        GRU     necesito cambiar mi reserva           1
# 6            n-grama conteos           reserva del hotel por           1
# 7   feedforward ventana fija           reserva del hotel por           1
# 8                        GRU           reserva del hotel por           1
# 9            n-grama conteos      quiero una habitación para           1
# 10  feedforward ventana fija      quiero una habitación para           1
# 11                       GRU      quiero una habitación para           1
#
#                                                  text
# 0   quiero reservar una habitación para <num> adul...
# 1   quiero reservar una habitación para <num> adul...
# 2   quiero reservar una habitación para <num> adul...
# 3   necesito cambiar mi reserva de habitación a no...
# 4                necesito cambiar mi reserva de hotel
# 5   necesito cambiar mi reserva a nombre de norman...
# 6   reserva del hotel por <num> noches desde el <n...
# 7                         reserva del hotel por favor
# 8                  reserva del hotel por <num> noches
# 9            quiero una habitación para <num> adultos
# 10  quiero una habitación para <num> adultos y <nu...
# 11  quiero una habitación para <num> personas a la...

# %% [markdown]
# ## 12. Guía de interpretación de los resultados
#
# Para fines de enseñanza, conviene leer las comparaciones en este orden:
#
# - **Perplexity:** menor es mejor como predictor del conjunto de validación, siempre que los modelos usen el mismo vocabulario y la misma partición de datos.
# - **n-grama vs. feedforward:** ambos usan una ventana finita, pero el n-grama memoriza contextos exactos, mientras que la red feedforward aprende embeddings y puede suavizar por similitud entre tokens.
# - **feedforward vs. GRU:** ambos son neuronales y usan embeddings; la diferencia conceptual es que la red feedforward ve una ventana fija explícita, mientras que la GRU actualiza un estado recurrente.
# - **Ejemplos generados:** no deben evaluarse solo por “sonar bien”; también revisa repetición, tokens raros, deriva de dominio y si el texto respeta el prompt.
# - **Distribución del siguiente token:** esta tabla suele ser más informativa que una muestra aislada, porque permite ver qué alternativas considera plausibles cada modelo después del mismo contexto.

# %% [markdown]
# ## 13. Guardar checkpoint
#
# El checkpoint guarda pesos, vocabulario y configuracion basica. En Colab puedes descargar el archivo desde el panel lateral de archivos.

# %%
#@title Guardar modelo
SAVE_PATH = 'tiny_gru_lm_es.pt'
checkpoint = {
    'model_state_dict': model.state_dict(),
    'itos': itos,
    'stoi': stoi,
    'config': {
        'dataset_name': DATASET_NAME,
        'tokenizer': TOKENIZER,
        'lowercase': LOWERCASE,
        'normalize_slots': NORMALIZE_SLOTS,
        'seq_len': SEQ_LEN,
        'stride': STRIDE,
        'lr': LR,
        'weight_decay': WEIGHT_DECAY,
        'emb_dim': EMB_DIM,
        'hidden_dim': HIDDEN_DIM,
        'num_layers': NUM_LAYERS,
    },
    'best_epoch': best_epoch,
    'best_val_loss': best_val_loss,
    'history': history,
}
torch.save(checkpoint, SAVE_PATH)
print(f'checkpoint guardado en: {SAVE_PATH}')
# Out:
# checkpoint guardado en: tiny_gru_lm_es.pt

# %% [markdown]
# ## 14. Exportar resultados
#
# Esta celda guarda una carpeta `SimpleNeuralLM/runs/latest/` cuando detecta el repo, o `runs/latest/` si el notebook corre aislado en Colab. Tambien crea `latest.zip` para descargar/sincronizar los resultados con el workspace local.

# %%
#@title Exportar resultados para iteracion
import shutil

PROJECT_DIR = Path.cwd()
if PROJECT_DIR.name != 'SimpleNeuralLM' and (PROJECT_DIR / 'SimpleNeuralLM').exists():
    PROJECT_DIR = PROJECT_DIR / 'SimpleNeuralLM'

RUN_DIR = PROJECT_DIR / 'runs' / 'latest'
RUN_DIR.mkdir(parents=True, exist_ok=True)

best_row = min(history, key=lambda row: row['val_loss']) if history else {}
best_val_ppl = best_row.get('val_ppl')

run_config = {
    'dataset_name': DATASET_NAME,
    'tokenizer': TOKENIZER,
    'lowercase': LOWERCASE,
    'normalize_slots': NORMALIZE_SLOTS,
    'max_texts': MAX_TEXTS,
    'min_freq': MIN_FREQ,
    'seq_len': SEQ_LEN,
    'stride': STRIDE,
    'batch_size': BATCH_SIZE,
    'epochs_requested': EPOCHS,
    'emb_dim': EMB_DIM,
    'hidden_dim': HIDDEN_DIM,
    'num_layers': NUM_LAYERS,
    'lr': LR,
    'weight_decay': WEIGHT_DECAY,
    'grad_clip': GRAD_CLIP,
    'early_stop_patience': EARLY_STOP_PATIENCE,
    'sample_max_new': globals().get('SAMPLE_MAX_NEW'),
    'sample_temperature': globals().get('SAMPLE_TEMPERATURE'),
    'sample_top_k': globals().get('SAMPLE_TOP_K'),
    'samples_per_prompt': globals().get('SAMPLES_PER_PROMPT'),
    'render_sample_slots': globals().get('RENDER_SAMPLE_SLOTS'),
    'compare_models': globals().get('COMPARE_MODELS'),
    'comparison_epochs': globals().get('COMPARISON_EPOCHS'),
    'ff_context_size': globals().get('FF_CONTEXT_SIZE'),
    'ff_hidden_dim': globals().get('FF_HIDDEN_DIM'),
    'ff_dropout': globals().get('FF_DROPOUT'),
    'ngram_order': globals().get('NGRAM_ORDER'),
    'ngram_add_k': globals().get('NGRAM_ADD_K'),
    'topk_analysis': globals().get('TOPK_ANALYSIS'),
    'device': device,
    'cwd': str(Path.cwd()),
    'project_dir': str(PROJECT_DIR),
}

summary = {
    'dataset_name': DATASET_NAME,
    'num_texts': len(texts),
    'train_texts': len(train_texts),
    'val_texts': len(val_texts),
    'vocab_size': len(itos),
    'train_tokens': int(len(train_ids)),
    'val_tokens': int(len(val_ids)),
    'train_windows': len(train_ds),
    'val_windows': len(val_ds),
    'best_epoch': int(best_epoch),
    'best_val_loss': float(best_val_loss),
    'best_val_ppl': float(best_val_ppl) if best_val_ppl is not None else None,
    'final_epoch': int(history[-1]['epoch']) if history else None,
    'checkpoint_path': SAVE_PATH,
    'run_dir': str(RUN_DIR),
}

with (RUN_DIR / 'config.json').open('w', encoding='utf-8') as f:
    json.dump(run_config, f, ensure_ascii=False, indent=2)

with (RUN_DIR / 'summary.json').open('w', encoding='utf-8') as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

metric_fields = ['epoch', 'train_loss', 'val_loss', 'train_ppl', 'val_ppl', 'is_best']
with (RUN_DIR / 'metrics.csv').open('w', encoding='utf-8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=metric_fields)
    writer.writeheader()
    for row in history:
        writer.writerow({field: row.get(field) for field in metric_fields})

samples = globals().get('generated_samples', [])
if not samples:
    samples = []
    for prompt in prompts:
        for sample_idx in range(1, globals().get('SAMPLES_PER_PROMPT', 1) + 1):
            samples.append({
                'prompt': prompt,
                'sample_idx': sample_idx,
                'text': sample(
                    prompt=prompt,
                    max_new=globals().get('SAMPLE_MAX_NEW', 18),
                    temperature=globals().get('SAMPLE_TEMPERATURE', 0.55),
                    top_k=globals().get('SAMPLE_TOP_K', 6),
                ),
            })
    if globals().get('RENDER_SAMPLE_SLOTS'):
        for item in samples:
            item['rendered_text'] = render_slots(item['text'])

OFF_DOMAIN_TERMS = ['mesa', 'cena', 'restaurante', 'spa', 'cepillo']

def sample_flags(item):
    prompt = item.get('prompt', '').lower()
    text = item.get('text', '').lower()
    flags = []
    if '<unk>' in text:
        flags.append('unk_token')
    if any(term in text for term in OFF_DOMAIN_TERMS):
        flags.append('possible_domain_drift')
    if len(text.split()) <= len(prompt.split()) + 1:
        flags.append('short_or_echo')
    if re.search(r'\b(\w+)\s+\1\b', text):
        flags.append('adjacent_repeat')
    if 'habitación para la habitación' in text or 'habitaciÃ³n para la habitaciÃ³n' in text:
        flags.append('phrase_repeat')
    return flags

for item in samples:
    item['flags'] = sample_flags(item)

quality_summary = {
    'num_samples': len(samples),
    'flagged_samples': sum(1 for item in samples if item.get('flags')),
    'flag_counts': dict(Counter(flag for item in samples for flag in item.get('flags', []))),
}
summary['sample_quality'] = quality_summary

best_is_final = bool(history) and best_epoch == history[-1]['epoch']
if quality_summary['flagged_samples'] == 0 and best_is_final:
    agent_recommendation = 'stable_keep_current_settings'
    next_experiment_suggestions = [
        'freeze_current_hotels_baseline',
        'try_multi3_nlu_es_banking_same_settings',
        'try_simple_tico19_es_same_gru_pipeline',
    ]
elif quality_summary['flagged_samples'] > 0:
    agent_recommendation = 'review_sampling_or_prompts'
    next_experiment_suggestions = ['tighten_sampling_or_prompts', 'inspect_flagged_samples']
elif not best_is_final:
    agent_recommendation = 'reduce_epochs_or_use_best_checkpoint'
    next_experiment_suggestions = ['set_epochs_to_best_epoch', 'keep_best_checkpoint_restore_enabled']
else:
    agent_recommendation = 'inspect_manually'
    next_experiment_suggestions = ['review_metrics_and_samples_manually']

summary['agent_recommendation'] = agent_recommendation
summary['next_experiment_suggestions'] = next_experiment_suggestions
run_config['off_domain_terms'] = OFF_DOMAIN_TERMS

with (RUN_DIR / 'summary.json').open('w', encoding='utf-8') as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

with (RUN_DIR / 'config.json').open('w', encoding='utf-8') as f:
    json.dump(run_config, f, ensure_ascii=False, indent=2)

with (RUN_DIR / 'samples.md').open('w', encoding='utf-8') as f:
    f.write(f'# Samples: {DATASET_NAME}\n\n')
    for item in samples:
        sample_idx = item.get('sample_idx')
        suffix = f' [{sample_idx}]' if sample_idx is not None else ''
        f.write(f"## Prompt: {item['prompt']}{suffix}\n")
        f.write(item['text'].strip() + '\n')
        rendered = item.get('rendered_text')
        if rendered and rendered != item['text']:
            f.write(f"Rendered: {rendered.strip()}\n")
        if item.get('flags'):
            f.write(f"Flags: {', '.join(item['flags'])}\n")
        f.write('\n')


# Exportes adicionales de la comparacion didactica, si se ejecuto.
comparison_export_files = []
if 'comparison_df' in globals():
    comparison_df.to_csv(RUN_DIR / 'comparison_metrics.csv', index=False)
    comparison_export_files.append('comparison_metrics.csv')
if 'comparison_samples_df' in globals():
    comparison_samples_df.to_csv(RUN_DIR / 'comparison_samples.csv', index=False)
    comparison_export_files.append('comparison_samples.csv')
if 'next_token_df' in globals():
    next_token_df.to_csv(RUN_DIR / 'next_token_distribution.csv', index=False)
    comparison_export_files.append('next_token_distribution.csv')

summary['comparison_export_files'] = comparison_export_files

agent_artifact = {
    'config': run_config,
    'summary': summary,
    'metrics': history,
    'samples': samples,
    'comparison_metrics': comparison_df.to_dict(orient='records') if 'comparison_df' in globals() else None,
    'comparison_samples': comparison_samples_df.to_dict(orient='records') if 'comparison_samples_df' in globals() else None,
    'next_token_distribution': next_token_df.to_dict(orient='records') if 'next_token_df' in globals() else None,
}

with (RUN_DIR / 'agent_artifact.json').open('w', encoding='utf-8') as f:
    json.dump(agent_artifact, f, ensure_ascii=False, indent=2)

checkpoint_file = Path(SAVE_PATH)
if checkpoint_file.exists():
    shutil.copyfile(checkpoint_file, RUN_DIR / checkpoint_file.name)

zip_path = shutil.make_archive(str(RUN_DIR.parent / 'latest'), 'zip', root_dir=RUN_DIR.parent, base_dir='latest')

print(f'Resultados exportados en: {RUN_DIR}')
print(f'ZIP exportado en: {zip_path}')
print(f'Recomendacion agente: {agent_recommendation}')
print('Archivos:', ', '.join(p.name for p in sorted(RUN_DIR.iterdir())))
print('AGENT_ARTIFACT_JSON_START')
print(json.dumps(agent_artifact, ensure_ascii=False))
print('AGENT_ARTIFACT_JSON_END')
# Out:
# Resultados exportados en: /content/runs/latest
# ZIP exportado en: /content/runs/latest.zip
# Recomendacion agente: stable_keep_current_settings
# Archivos: agent_artifact.json, comparison_metrics.csv, comparison_samples.csv, config.json, metrics.csv, next_token_distribution.csv, samples.md, summary.json, tiny_gru_lm_es.pt
# AGENT_ARTIFACT_JSON_START
# {"config": {"dataset_name": "multi3_nlu_es_hotels", "tokenizer": "word", "lowercase": true, "normalize_slots": true, "max_texts": 20000, "min_freq": 1, "seq_len": 48, "stride": 8, "batch_size": 64, "epochs_requested": 11, "emb_dim": 128, "hidden_dim": 256, "num_layers": 1, "lr": 0.001, "weight_decay": 0.0001, "grad_clip": 1.0, "early_stop_patience": 3, "sample_max_new": 18, "sample_temperature": 0.55, "sample_top_k": 6, "samples_per_prompt": 3, "render_sample_slots": true, "compare_models": true, "comparison_epochs": 6, "ff_context_size": 3, "ff_hidden_dim": 256, "ff_dropout": 0.1, "ngram_order": 4, "ngram_add_k": 0.1, "topk_analysis": 8, "device": "cpu", "cwd": "/content", "project_dir": "/content", "off_domain_terms": ["mesa", "cena", "restaurante", "spa", "cepillo"]}, "summary": {"dataset_name": "multi3_nlu_es_hotels", "num_texts": 1009, "train_texts": 908, "val_texts": 101, "vocab_size": 1028, "train_tokens": 10272, "val_tokens": 1155, "train_windows": 1278, "val_windows": 139, "best_epoch": 11, "best_val_loss": 3.243018570563776, "best_val_ppl": 25.610913534016426, "final_epoch": 11, "checkpoint_path": "tiny_gru_lm_es.pt", "run_dir": "/content/runs/latest", "sample_quality": {"num_samples": 12, "flagged_samples": 0, "flag_counts": {}}, "agent_recommendation": "stable_keep_current_settings", "next_experiment_suggestions": ["freeze_current_hotels_baseline", "try_multi3_nlu_es_banking_same_settings", "try_simple_tico19_es_same_gru_pipeline"], "comparison_export_files": ["comparison_metrics.csv", "comparison_samples.csv", "next_token_distribution.csv"]}, "metrics": [{"epoch": 1, "train_loss": 5.624917163908575, "val_loss": 4.582029884667706, "train_ppl": 277.24931732209325, "val_ppl": 97.71253821744328, "is_best": true}, {"epoch": 2, "train_loss": 4.094178086715125, "val_loss": 4.052311760058506, "train_ppl": 59.99001230095816, "val_ppl": 57.530299685096054, "is_best": true}, {"epoch": 3, "train_loss": 3.5471074943064895, "val_loss": 3.7421317460725634, "train_ppl": 34.71276526260738, "val_ppl": 42.187828112018124, "is_best": true}, {"epoch": 4, "train_loss": 3.1630169647586923, "val_loss": 3.5684418866960264, "train_ppl": 23.641814964968145, "val_ppl": 35.461297365064326, "is_best": true}, {"epoch": 5, "train_loss": 2.877925049344512, "val_loss": 3.4447694682388854, "train_ppl": 17.7773477642568, "val_ppl": 31.33605865714103, "is_best": true}, {"epoch": 6, "train_loss": 2.6455220814228806, "val_loss": 3.369256456978887, "train_ppl": 14.09079970786189, "val_ppl": 29.056913958069487, "is_best": true}, {"epoch": 7, "train_loss": 2.442170006568443, "val_loss": 3.3139864523633777, "train_ppl": 11.497964348980991, "val_ppl": 27.49451285900247, "is_best": true}, {"epoch": 8, "train_loss": 2.257993085843297, "val_loss": 3.2807166473471003, "train_ppl": 9.563876015472053, "val_ppl": 26.594824982945113, "is_best": true}, {"epoch": 9, "train_loss": 2.0935425471065563, "val_loss": 3.252506473939196, "train_ppl": 8.113607148473704, "val_ppl": 25.855063812571835, "is_best": true}, {"epoch": 10, "train_loss": 1.9430579023555223, "val_loss": 3.248072130216969, "train_ppl": 6.980062719638849, "val_ppl": 25.740667396633064, "is_best": true}, {"epoch": 11, "train_loss": 1.807136790106927, "val_loss": 3.243018570563776, "train_ppl": 6.092976961439148, "val_ppl": 25.610913534016426, "is_best": true}], "samples": [{"prompt": "quiero reservar una habitación", "sample_idx": 1, "text": "quiero reservar una habitación para <num> adultos y un niño", "rendered_text": "quiero reservar una habitación para 3 adultos y un niño", "flags": []}, {"prompt": "quiero reservar una habitación", "sample_idx": 2, "text": "quiero reservar una habitación desde el <num> de <mes>", "rendered_text": "quiero reservar una habitación desde el 5 de julio", "flags": []}, {"prompt": "quiero reservar una habitación", "sample_idx": 3, "text": "quiero reservar una habitación para <num> adultos", "rendered_text": "quiero reservar una habitación para 4 adultos", "flags": []}, {"pro ...
# AGENT_ARTIFACT_JSON_END

# %% [markdown]
# ## Siguientes experimentos utiles
#
# - Usa `multi3_nlu_es_hotels` para entrenar solo con hoteles, o `multi3_nlu_es_banking` para banca.
# - Prueba `TOKENIZER = 'char'` si `SEQ_LEN` pequeno o vocabulario grande te da problemas.
# - Sube `EPOCHS` a 10-20 si la perplexity de validacion sigue bajando.
# - Cuando esta version funcione, el siguiente paso natural es reemplazar `word/char` por BPE con `sentencepiece`.
#
# - Para una comparacion rapida, baja `COMPARISON_EPOCHS`; para una comparacion mas justa, igualalo a `EPOCHS`.
# - Prueba `FF_CONTEXT_SIZE = 1, 3, 5, 10` y `NGRAM_ORDER = 2, 3, 4, 5` para ver el efecto de aumentar el contexto.
# - Compara las tablas de siguiente token antes de juzgar solo por muestras generadas, porque una muestra aislada puede ser ruidosa.
